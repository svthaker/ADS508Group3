# %% [markdown]
# # Setup Project Dependencies
#
# *This Notebook will take a few minutes to complete.*

# %%
# !python --version
# Out:
# Python 3.11.11

# %%
# !pip list
# Out:
# Package                                   Version
# ----------------------------------------- -----------
# absl-py                                   2.4.0
# accelerate                                1.12.0
# adagio                                    0.2.6
# aiobotocore                               2.25.2
# aiohappyeyeballs                          2.6.1
# aiohttp                                   3.13.3
# aiohttp-cors                              0.8.1
# aioitertools                              0.13.0
# aiosignal                                 1.4.0
# aiosqlite                                 0.19.0
# alembic                                   1.18.4
# altair                                    5.5.0
# amazon-q-developer-jupyterlab-ext         3.4.8
# amazon_sagemaker_jupyter_ai_q_developer   1.2.9
# amazon_sagemaker_jupyter_scheduler        3.1.16
# amazon-sagemaker-sql-editor               0.1.21
# amazon-sagemaker-sql-execution            0.1.9
# ...

# %% [markdown]
# ## Pip

# %%
# !pip install --disable-pip-version-check -q pip --upgrade > /dev/null
# !pip install --disable-pip-version-check -q wrapt --upgrade > /dev/null

# %% [markdown]
# ## AWS CLI and AWS Python SDK (boto3)

# %%
#!pip install --disable-pip-version-check -q awscli==1.18.216 boto3==1.16.56 botocore==1.19.56

# %%
# Check boto3 version, in modern Amazon SageMaker Studio environments, boto3 is already preinstalled
import boto3
import botocore
print(boto3.__version__)
print(botocore.__version__)
# Out:
# 1.40.70
# 1.40.70

# %% [markdown]
# ## SageMaker

# %%
# Install SageMaker SDK v2 and related debugging/experiment tools.
# The course notebooks use the SageMaker v2 API (e.g., Session, clarify),
# which is not compatible with the newer SageMaker SDK v3 package structure.
# Installing "sagemaker<3" ensures the correct API is available.

# !pip install --disable-pip-version-check -q "sagemaker<3"
# !pip install --disable-pip-version-check -q smdebug
# !pip install --disable-pip-version-check -q sagemaker-experiments

# Note: Some preinstalled Studio packages may report protobuf version conflicts.
# If the lab runs successfully, these warnings can be ignored unless a later cell
# fails with a protobuf-related import or runtime error.

# %% [markdown]
# ## PyTorch

# %%
# !conda install -y pytorch==1.6.0 -c pytorch
# Out:
# Channels:
#  - pytorch
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: | WARNING conda.models.version:get_matcher(563): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 0.39.0.*, but conda is ignoring the .* and treating it as 0.39.0
# WARNING conda.models.version:get_matcher(563): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 0.10.0.*, but conda is ignoring the .* and treating it as 0.10.0
# WARNING conda.models.version:get_matcher(563): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 2.*, but conda is ignoring the .* and treating it as 2
# ...

# %% [markdown]
# ## TensorFlow

# %%
# !pip install --disable-pip-version-check -q tensorflow==2.8.1
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.8.1 (from versions: 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.0.post1, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.19.1, 2.20.0rc0, 2.20.0, 2.21.0rc0, 2.21.0rc1, 2.21.0)
# ERROR: No matching distribution found for tensorflow==2.8.1

# %% [markdown]
# ## Hugging Face Transformers (BERT)

# %%
# !pip install --disable-pip-version-check -q transformers==3.5.1
# Out:
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2 lines of output]
#       /bin/sh: 1: pkg-config: not found
#       Failed to find sentencepiece pkgconfig
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'sentencepiece' when getting requirements to build wheel

# %% [markdown]
# ## TorchServe

# %%
# !pip install --disable-pip-version-check -q torchserve==0.3.0
# !pip install --disable-pip-version-check -q torch-model-archiver==0.3.0

# %% [markdown]
# ## PyAthena

# %%
# !pip install --disable-pip-version-check -q PyAthena==2.1.0
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# amazon-sagemaker-sql-execution 0.1.9 requires pyathena<4,>=3.3.0, but you have pyathena 2.1.0 which is incompatible.
# sagemaker-studio 1.1.6 requires pyathena>=3.18.0, but you have pyathena 2.1.0 which is incompatible.

# %% [markdown]
# ## Redshift

# %%
# !pip install --disable-pip-version-check -q SQLAlchemy==1.3.22
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# alembic 1.18.4 requires SQLAlchemy>=1.4.23, but you have sqlalchemy 1.3.22 which is incompatible.
# jupyter-scheduler 2.11.0 requires sqlalchemy<3,>=2.0, but you have sqlalchemy 1.3.22 which is incompatible.
# langchain 0.3.27 requires SQLAlchemy<3,>=1.4, but you have sqlalchemy 1.3.22 which is incompatible.
# langchain-community 0.3.31 requires SQLAlchemy<3.0.0,>=1.4.0, but you have sqlalchemy 1.3.22 which is incompatible.
# mlflow 2.22.0 requires sqlalchemy<3,>=1.4.0, but you have sqlalchemy 1.3.22 which is incompatible.
# optuna 4.7.0 requires sqlalchemy>=1.4.2, but you have sqlalchemy 1.3.22 which is incompatible.
# sagemaker-studio 1.1.6 requires pyathena>=3.18.0, but you have pyathena 2.1.0 which is incompatible.
# ...

# %% [markdown]
# ## AWS Data Wrangler

# %%
# !pip install --disable-pip-version-check -q awswrangler==2.15.0
# Out:
# ERROR: Ignored the following yanked versions: 3.2.0
# ...

# %% [markdown]
# ## StepFunctions

# %%
# !pip install --disable-pip-version-check -q stepfunctions==2.0.0rc1

# %% [markdown]
# ## Zip

# %%
# !conda install -y zip
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - zip
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     arro3-core-0.8.0           |  py311hc8fb587_0         2.0 MB  conda-forge
#     deltalake-1.3.2            |  py310h1c74b4c_0       173.0 MB  conda-forge
#     papermill-2.7.0            |     pyhd8ed1ab_0          69 KB  conda-forge
#     sagemaker-code-editor-1.8.5|       hd6838e5_1        48.5 MB  conda-forge
#     sagemaker-jupyterlab-extension-0.5.2|     pyhd8ed1ab_0         437 KB  conda-forge
# ...

# %% [markdown]
# ## Matplotlib

# %%
# !pip install --disable-pip-version-check -q matplotlib==3.1.3
# Out:
#   error: subprocess-exited-with-error
#
#   × Building wheel for matplotlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [548 lines of output]
#       <string>:32: SetuptoolsDeprecationWarning: The test command is disabled and references to it are deprecated.
#       !!
#
#               ********************************************************************************
#               Please remove any references to `setuptools.command.test` in all supported versions of the affected package.
#
#               This deprecation is overdue, please update your project and remove deprecated
#               calls to avoid build errors in the future.
#               ********************************************************************************
#
#       !!
#       /tmp/pip-build-env-2_egcsg8/overlay/lib/python3.11/site-packages/setuptools/dist.py:810: SetuptoolsDeprecationWarning: The namespace_packages parameter is deprecated.
#       !!
#
# ...

# %% [markdown]
# ## Seaborn

# %%
# !pip install --disable-pip-version-check -q seaborn==0.10.0

# %% [markdown]
# # GeoPandas

# %%
# !pip install geopandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.5/32.5 MB 224.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 262.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 223.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Summarize

# %%
# !pip install protobuf==3.20.*
# !python --version
# Out:
# ...
#   Using cached protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Using cached protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.28.3
#     Uninstalling protobuf-5.28.3:
#       Successfully uninstalled protobuf-5.28.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# databricks-sdk 0.73.0 requires protobuf!=5.26.*,!=5.27.*,!=5.28.*,!=5.29.0,!=5.29.1,!=5.29.2,!=5.29.3,!=5.29.4,!=6.30.0,!=6.30.1,!=6.31.0,<7.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.67.1 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# ...
# Python 3.11.11

# %%
# !pip list
# Out:
# Package                                   Version
# ----------------------------------------- -----------
# absl-py                                   2.4.0
# accelerate                                1.12.0
# adagio                                    0.2.6
# aiobotocore                               2.25.2
# aiohappyeyeballs                          2.6.1
# aiohttp                                   3.13.3
# aiohttp-cors                              0.8.1
# aioitertools                              0.13.0
# aiosignal                                 1.4.0
# aiosqlite                                 0.19.0
# alembic                                   1.18.4
# altair                                    5.5.0
# amazon-q-developer-jupyterlab-ext         3.4.8
# amazon_sagemaker_jupyter_ai_q_developer   1.2.9
# amazon_sagemaker_jupyter_scheduler        3.1.16
# amazon-sagemaker-sql-editor               0.1.21
# amazon-sagemaker-sql-execution            0.1.9
# ...

# %%
setup_dependencies_passed = True

# %%
# %store setup_dependencies_passed
# Out:
# Stored 'setup_dependencies_passed' (bool)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# setup_dependencies_passed               -> True
# setup_iam_roles_passed                  -> True
# setup_instance_check_passed             -> True
# setup_s3_bucket_passed                  -> True

# %% [markdown]
# # Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
